# %% [markdown]
# # FIT9136 Algorithms and programming foundations in Python

# %% [markdown]
# ## Week 3– Lab activities
# ### Control structure

# %% [markdown]
# Agenda
# - Truth table
# - Comparisons
# - Logical
# - Documenting
# - Loop
# - File reading

# %% [markdown]
# ## Task 1: Truth Table

# %% [markdown]
# Evaluate the following:
#
# ### A. True and False

# %% [markdown]
# B. False and True

# %% [markdown]
# C.True or False

# %% [markdown]
# D.False or False

# %% [markdown]
# E.True and not False

# %% [markdown]
# F.True or not False or False or not True

# %% [markdown]
# G.(True or False) and False or True

# %% [markdown]
# ## Task 2: Comparisons
#
# Evaluate the following comparisons:
#
# A. 8 <= 10

# %% [markdown]
# B. 10 > 5 > 3

# %% [markdown]
# C. 5 == 6

# %% [markdown]
# D.5 <= 5

# %% [markdown]
# E.5 > True

# %% [markdown]
# F.-1 < False

# %% [markdown]
# ## Task 3: Efficient Logic
# How can the following code be written more efficiently?

# %%
x = int (input("What is your number?")) 
if x > 5:
    print ("Large") 
if x <= 5:
    print ("Small")
# Out:
# What is your number?7
# Large

# %% [markdown]
# ## Task 4: Is equal equal? (Week 3 Submission)
# What is the purpose of the command is? How is it different to ==?

# %% [markdown]
# ## Task 5a: Documenting your Code (Week 3 Submission)
# Write a While loop that prints all the numbers between 0 and 10.
# Now write a For loop that does the same.
# How are they different? List the advantages/disadvantages you can see.

# %% [markdown]
# ## Task 6: Varying Range
# What will the following print:

# %%
for i in range(5 ,10 ,2): 
print (i)

# %% [markdown]
# ## Task 6a: (Week 3 Submission)
# What if you change the range to (1,9, 3)?

# %% [markdown]
# How about (5,-4,-1)?

# %% [markdown]
# ## Task 7: Confusing Functionality
# What does the following print, and why?

# %%
def func (): 
    return print (1) 
print(func())
# Out:
# 1
# None

# %% [markdown]
# ## Task 7a: Upgrading
# Using your calculator script from last week go ahead and change the code to not only accept input from the user for the numbers to be used, but also ask what operation to use to perform the calculation.
# (Hint: You will need to create if statements for each of the operations available. While updating the code, go ahead and try to use functions to streamline the functionality. Each operation should be a function, and you should have a ‘menu’ that presents the operations available to the user. )

# %% [markdown]
# For a challenge, edit the script so that it repeatedly asks for new input and performs the calculation until the user types in “quit” for one of the inputs.

# %% [markdown]
# Further, for those who want to push ahead, look into the “str” library for ways to validate the input to be an integer or float.

# %% [markdown]
# ## Task 8: Coins
# Write a script that flips a coin and presents the outcome. (Hint: To do this you will need to make use of if statements and will need to import “random”). You can use whatever function you want from that library, but you should try “random.random()” first.

# %% [markdown]
# ## Task 9: Efficient File Reading
# For a file of your choice, print the contents of it using a For loop. Try and take this further by reading in some data using a For loop and perform some kind of calculation with it (such as a sequence of numbers).

# %% [markdown]
# # Task 10: Week 3 Moodle submission
# Task 4,5a & 6
