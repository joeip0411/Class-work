# %%
# import packages
import os
import re
import langid

# %%
files_names = [f for f in os.listdir('.') if re.match(r'2020-\d{2}-\d{2}_\d+\.txt', f)]
files_names
# Out:
# ['2020-04-18_30.txt',
#  '2020-04-18_8.txt',
#  '2020-05-07_3830.txt',
#  '2020-05-07_3831.txt',
#  '2020-05-07_3832.txt',
#  '2020-05-07_3833.txt',
#  '2020-05-07_3834.txt',
#  '2020-05-12_1.txt',
#  '2020-05-12_26.txt',
#  '2020-06-07_3831.txt',
#  '2020-06-07_3832.txt',
#  '2020-06-07_3833.txt',
#  '2020-06-07_3834.txt']

# %% [markdown]
# ## Put everything into dict

# %%
# dictionary to store all the extracted information
output_dict = {}
id_set = set([])

# %%
# function to transform ascii string into unicode character
cp2chr = lambda c: (b'\\u' + c.encode('ascii')).decode('raw_unicode_escape') 

# for every txt file
for name in range(len(files_names)):
    f = open(files_names[name],'r',encoding="utf-8")
    
    # extract date from file name
    date = re.findall('2020-\d{2}-\d{2}', files_names[name])[0]
    # extract batch no. from file name
    batch_no = int(re.findall(r'_\d+', files_names[name])[0][1:])
    
    # add date as a key in dict
    # add batch no. as a key under date sub-dict
    if output_dict.get(date) is not None:
        output_dict[date][batch_no] = {}
    else:
        output_dict[date] = {}
        output_dict[date][batch_no] = {}
    
    # read the file as one big string
    file_string = f.read()
    
    # make adjustment to match the sample output format
    file_string = file_string.replace('&', '&amp;').replace('\\"', "&quot;").replace('\\n','\n').replace("\'", '&apos;')
    
    # find all individual tweet
    twit_list= re.findall(r'({"created_at[\w\W]*?}|{"text[\w\W]*?}|{"id[\w\W]*?})', file_string)
    
    # list to store tweet ids
    id_list = []
    
    # append all ids found into id_list
    for t in range(len(twit_list)):
        id_list.append(re.findall(r'"id":"(\d+)"', twit_list[t])[0])
    
    # list to store tweet content
    content_list = []
    
    # append all tweets found into list
    for i in range(len(twit_list)):
        content = re.findall(r'"text":"(?:[\w\W])*?"',twit_list[i])[0][8:-1]
        content_list.append(content)
    
    # find all unicode characters in the form \uXXXX
    for i in range(len(content_list)):
        unit_code_char = re.findall(r'\\\w{5}',content_list[i])
        
        # transform all the unicode character string into actual unicode character
        for char in unit_code_char:
            content_list[i] = content_list[i].replace(char, cp2chr(char[2:]))
        
        # Here is the trick, each emoji is a pair of unicode character \uXXXX\uXXXX, which is encode using utf-16,
        # However, our output file only supports utf-8 encoding, therefore it will throw an error when it encounters
        # an utf-8 character e.g. \uXXXX, which has no meaning , emoji must work in pairs! Since all the other characters
        # of the tweets are utf-8 characters except the emojis, we can try to find all the emojis by trying to encode all the
        # characters into utf-8, when we encounter a character like \uXXXX, it will throw an error, in this case, we will try
        # to encode the current character together with the next character in utf-16, then encode this character in utf-8 and
        # decode it in utf-8, in this manner, we can transform all the characters in the tweets into utf-8 format.
        # since string is immutable, I create a new empty string, and add each succesive characters to the new string by using
        # the following while loop
        
        new_content = ''

        j = 0
        while j < len(content_list[i]):
            try:
                new_content = new_content + content_list[i][j].encode('utf-8').decode('utf-8')
                j+=1
            except:
                new_content = new_content + (content_list[i][j]+content_list[i][j+1]).encode('utf-16', 'surrogatepass').decode('utf-16').encode('utf-8').decode('utf-8')
                j+=2
        content_list[i] = new_content        
    
    # after all the transformation is completed, we can then remove all the non-English tweets by using the langid package,
    # please be aware that this must be done last, because if we haven't change all the unicode characters back to proper form,
    # when python encounter something like \uA1B2, since all this characters are English characters, it will treat emojis as English,
    # if a single tweet only consists of emoji, langid will treat that tweet as English tweets, which is incorrect.
    for i in range(len(content_list)-1,-1,-1):
        language = langid.classify(content_list[i])[0]
        # if language is not english, remove corresponding item from id list and content list, you must do this be iterating
        # the list backwards 
        if language != 'en':
            content_list.pop(i)
            id_list.pop(i)
    
    # remove duplicate
    for j in range(len(id_list)-1,-1,-1):
        if id_list[j] in id_set:
            id_list.pop(j)
            content_list.pop(j)
        else:
            id_set.add(id_list[j])
            
    # put the index and content into the outout dict
    output_dict[date][batch_no]['ind'] = id_list
    output_dict[date][batch_no]['content'] = content_list

# %%
output_dict
# Out:
# {'2020-04-18': {30: {'ind': ['1251362171998498816',
#     '1251362173705752576',
#     '1251362173756100608',
#     '1251362173793771520',
#     '1251362176696086530',
#     '1251362177774018562',
#     '1251362178373873664',
#     '1251362179070058496',
#     '1251362181343576065',
#     '1251362181943263234',
#     '1251362184556212231',
#     '1251362185827307520',
#     '1251362185902579713',
#     '1251362186154344448',
#     '1251362186401849351',
#     '1251362186632531968',
#     '1251362186657771525',
#     '1251362186771005446',
#     '1251362186888450049',
#     '1251362189933494273',
#     '1251362190155747328',
#     '1251362190621241344',
#     '1251362190629597184',
#     '1251362193381175296',
#     '1251362193641074688',
#     '1251362193708404737',
#     '1251362194111057922',
#     '1251362194278809600',
#     '1251362194538799112',
#     '1251362194660323330',
#     '1251362195360739328',
#     '1251362195423637508',
#     '1251362195818020870',
#     '1251362199278321666',
#     '1251362199509049344',
#     '1251362199723008000',
#     '1251362199785877505',
#     '1251362199978868738',
#     '1251362200058580992',
#     '1251362200066961409',
#     '1251362201358733313',
#     '1251362202243792896',
#     '1251362202419736578',
#     '1251362203518803974',
#     '1251362204022120448',
#     '1251362204705869824',
#     '1251362206005985281',
#     '1251362207465639939',
#     '1251362208380006400',
#     '1251362208451305473',
#     '1251362208690458626'],
#    'content': ['If we do not follow the lockdown period sincerely, as a result of the COVID-19 infection, India as a nation is bound to fall back 21 years.\nMaking the right choice is our collective responsibility at this moment. https://t.co/oGhKLLuKxO',
#     '#Kerala is a role model for all other states of #India, \nI appeal the State Gov to look forward and implement the similar strategy. @HemantSorenJMM @BannaGupta76 @jharkhand181 @JharkhandCMO https://t.co/D5HUvQpiPP',
#     '@realDonaldTrump Saying, “I take no responsibility” doesn’t mean you’re not responsible for every American who has died and will die from the Coronavirus.',
#     'This is beautiful, we should also do this for all the medical worker&apos;s! when the virus finally settles down. \nLove to all of the patient&apos;s and medical worker&apos;s ❤ https://t.co/4OusOoCBeM',
#     'Reaction to London Real with David Icke https://t.co/1VAE60y7YI via @YouTube #londonreal #londonrealarmy #davidicke #nofearamericanbusiness #business #nofear #CoronaWillEndSoon #coronavirus #Agenda2030 #fearthelord #bible #kjv',
#     'For whatever nationalism the coronavirus stokes, it&apos;ll be thanks to borderless scientific collaboration and open source information that we find and develop a life-saving vaccine: https://t.co/aJYBVOlY5n',
#     'Wtaf. Nah, not surprised at all.\n\nOpt out. Raise your own meat. Hold your own keys. https://t.co/IGzNQFWnEY',
#     'Prior to #COVID19 video conferencing btw students &amp;amp; staff was essentially not allowed in CPS. CPS was quick to let schools ask for parental consent for Ss to use Zoom, etc. for academic remote learning, but not sped related services. @docswin sped Ss need remote learning equity. https://t.co/0ykDiUAXEi',
#     '#StayAtHome https://t.co/5qnqVDQ9Fp',
#     'Bret Baier says &apos;more and more dots&apos; point to Wuhan lab as origin of coronavirus pandemic https://t.co/GiHMmpQO8f #FoxNews',
#     'DHS: COVID-19 is changing potential terror targets; grocery stores, even testing sites should be vigilant https://t.co/8DaQws7zYC',
#     'Ottawa to provide $250 million to prop up strategic innovative firms hurt by COVID-19 https://t.co/ePXrpwT6Mm',
#     'Bret Baier says ‘more and more dots’ point to Wuhan lab as origin of coronavirus pandemic https://t.co/YNmgs61pkW',
#     'Dying alone from coronavirus: Group collects used iPads to virtually connect patients with family https://t.co/f8qz66CUXX',
#     'Coronavirus: People in tall buildings may be more at risk – here’s how to stay safe https://t.co/subJPxchUY',
#     'national Vineland day https://t.co/TuJSP4SDW7',
#     'https://t.co/vUWbsans10 https://t.co/I74ziligdA',
#     '&apos;Can confirm COVID-19 in 2 hours at low cost&apos;: Harsh Vardhan announces new test kit developed by Kerala-based institute https://t.co/5372wPejvV https://t.co/WFuFzPOC06',
#     '🤘Strong  country 🤘\n👇With👇 \n🤘 Global leadership🤘\n👉 The American president fulfilled to all the needs of the people.   Strengthen the American economy.  Fighting terrorism and liquidated it.\nHe is now protecting the health of the people and protecting them from CORONAVIRUS. https://t.co/SAvgck2jSg https://t.co/2LTr9HAW91',
#     'Ripple Makes Significant Effort to Battle COVID-19 Pandemic',
#     'I need to be up by 7 for my first day back at work and I CANT SLEEP! Pinche coronavirus! Te ooodio!!!',
#     'And @republic did a whole show on how migrant crisis was made up just to portray Modi a.k.a. India, in bad light https://t.co/GX0DEl0qAv',
#     'Gilead data suggests coronavirus patients are responding to treatment https://t.co/PoG9ijiqgo via @statnews on @refindcom',
#     'Many migrants on U.S. deportation flight had coronavirus, Guatemalan president says https://t.co/W8x5GVSGd5',
#     'If you have fever only take Tylenol!!! https://t.co/NHegQOpyzY',
#     'There&apos;s like 6 people in living in South Dakota and you choose Florida https://t.co/8rHUdAdVVu']},
#   8: {'ind': ['1251361301282029569',
#     '1251361303966425090',
#     '1251361304297615361',
#     '1251361304725651456',
#     '1251361304893325319',
#     '1251361305291874305',
#     '1251361306508025856',
#     '1251361306579517440',
#     '1251361306667479040',
#     '1251361308131446785',
#     '1251361308672434177',
#     '1251361310069215232',
#     '1251361310266269696',
#     '1251361310329061376',
#     '1251361312279613445',
#     '1251361313206480897',
#     '1251361313336393728',
#     '1251361314078781440',
#     '1251361314473041922',
#     '1251361315836264453',
#     '1251361318038147073',
#     '1251361320689008640',
#     '1251361320928239616',
#     '1251361321179889665',
#     '1251361321221750786',
#     '1251361321703968769',
#     '1251361322916184069',
#     '1251361324736667648',
#     '1251361325189459969',
#     '1251361325260976128',
#     '1251361325395173376',
#     '1251361325445513217',
#     '1251361325550190593',
#     '1251361329363013634',
#     '1251361329916624896',
#     '1251361330369421312',
#     '1251361331594264577',
#     '1251361333209108482',
#     '1251361334144520192',
#     '1251361335432155136',
#     '1251361335687868418',
#     '1251361335746523136',
#     '1251361336706994176',
#     '1251361337512325120'],
#    'content': ['@Coach_Keesha @BrandonBeckham_ @TheDemocrats @realDonaldTrump Democrats propose bill to undo Trump&apos;s move of firing coronavirus oversight leader.\n&quot;There are trillions of taxpayer dollars at stake, and Americans across the political spectrum want those funds to be spent without waste, fraud, abuse or profiteering.&quot;\nhttps://t.co/m9ljqeITeE',
#     '@Ska_Maria And over a month later, still we track Italy https://t.co/vEMV43dvsJ https://t.co/VuqOYihukZ',
#     '@GinSecurities @WCCO @carlquintanilla @GovTimWalz @GOP @DNC @CNN Where are you getting your information? COVID-19 does not care about your political affiliation.',
#     'Looking into reports that #coronavirus escaped from #Wuhan lab, says Donald #Trump https://t.co/W7kWVjOasU https://t.co/1dGhSMOE72',
#     'The presidency regret to announce the passing of ABBA KYARI, the chief was earlier tested positive of the COVID-19 and has been receiving treatment but unfortunately he died on Friday. -17th April 2020\n      \n                       Williams Victoria!',
#     'Years ago we been discussing with \u2066@KGeorgieva\u2069 &amp;amp; President Plevneliev what means global leadership. Today she is doing everything to take responsibility as leader &amp;amp; help countries in need to overcome #covid19 https://t.co/oVIvFDUpcl',
#     'I’m starting to get annoyed that people kept saying this Covid-19 is a sign of Qiyamah.\n\nVirus outbreaks are not something new guys, please...... we really have to be optimistic.',
#     'https://t.co/jGBCCngnqA - Fox News Radio https://t.co/pCW4lMzQJf - ‘I Believe In Our Freedoms And Liberties’: South Dakota Governor Responds To Critics Of State’s Coronavirus Response - https://t.co/4Xr1P9K1er',
#     'Parishioner of Louisiana Church That Defied Virus Lockdown Dies From COVID-19, But Pastor Claims It’s a Lie https://t.co/zmOhU7FLEv WOW THIS IS ONE CRAZY MF! HE DENIES THE MAN DIED FROM CORONAVIRUS? WHAT A LYING DANGEROUS MAN!',
#     'Maybe we can let them fall over dead from #COVID19 like people did in other countries - Iran, China, Italy, France, Spain - just stay aways from them. I hate that these same Trump followers will be giving #COVID to their family members and neighbors. #TrumpGenocide #GOPGenocide https://t.co/nHZZHJLzZQ',
#     'Most sailors on US carrier with COVID-19 are asymptomatic\nhttps://t.co/vlNHDE97uJ\n#aircraft #assigned #navy #photo #released #roosevelt #sailors #shows #theodore #this',
#     '@TheHimanshuGaur @the_rahulkumar @BabitaPhogat @timesofindia Was this in national media as well -\n\n“US Commission on Religious Freedom condemns the continued scapegoating and attacks of Muslims in India due to false rumors over the spread of coronavirus, often accompanied by dangerous rhetoric by politicians.”\n\nhttps://t.co/27tm4Z3mW3',
#     '@MissLindner @CityofJax @HaigisPaula @PatriciaBronso7 @lennycurry @JSOPIO @JFRDJAX @JaxBeachPD An update to #Duval County’s #COVID19 numbers... https://t.co/Tc2Nur3UM8',
#     '@KFC_UKI got some free advertising here! https://t.co/376nYLFR7j',
#     'Cases in the U.S. | CDC https://t.co/uymeptOcTV',
#     'Every business is now software driven! \nChange is the only constant\n#CXO Symposium organized by #HRIA\n\n#Webinar | 7th May 2020 | 4.00 PM to 5.30 PM\n#Learning in #COVID19 #Lockdown\n\n@HRInfotech',
#     'I wish him quick recovery.\nGet well Soon.\nMay the Almighty forgive you. https://t.co/e2Ee0WpFCw',
#     'Court Assistant David Lloyd-Owen, MD of Envisager, has written a fascinating report “How sewage is helping us to understand the dynamics of Covid-19 infections”. This key report has been widely distributed to the media and technical groups. Full details on our website shortly. https://t.co/BhGNH8VLU7',
#     'PakistanNet is out! https://t.co/XXnUU8Ikk2 Stories via @UNDP_Pakistan #undpinpakistan #covid19',
#     '@NYGovCuomo and thanks to you and the shithole known as NY &amp;amp; NYC, the rest of the country has suffered: &quot;New York City’s coronavirus outbreak grew so large by early March that the city became the primary source of new infections in the United States&quot; https://t.co/K05d5K3GPW',
#     '@Thomas1774Paine This is old news, rehashed: https://t.co/MkPxnzeP3J\n\n2 strains.\n1. Lethal L strain, originally bulk of cases. China, Iran, Italy.\n2. Safer S strain, more contagious and immunizes you to BOTH strains.\n\nS is the &quot;off switch&quot; for L.\n\nBioweapon.\n\nThe viral equivalent of a flashbang.',
#     '@SingleWindowUG is facilitating safe international trade of essential commodities during the COVID-19 period. @TradeMarkEastA @UNDAuthority @UNBSug @URAuganda https://t.co/ponEMMShlx',
#     'Seriously punchy from the EU&apos;s trade commissioner \nhttps://t.co/zucTW1zejP',
#     'With a work hat on, we’re all trying to make sense of the continually emerging picture on Coronavirus and the impacts on social trends. If there are any disability specific sources of information, then please let me know:)',
#     '@Blueber13415354 @Hedd_Wyn_John @afneil Coronavirus&apos;s don&apos;t tend to mutate rapidly,  + labs are working on this thing every single day.\n\nAs someone who has worked in labs, trust me when i say this sort of thing is identified quickly as peer reviews etc bring up red flags.\n\nThat is unless country&apos;s are sharing nothing',
#     'Of course he did, anyone who has ever worked for him is https://t.co/NvTOYeDVI4',
#     'Fresh greens, in quarantine! \n\n#spinach #tomatoes #onion #balsamic #covid19 #cleaneating https://t.co/4Mn5by3NKm',
#     '@LancetLab_ZA may I find out why is it sooooo difficult to have a Covid-19 test done on my employees at your Lab in Mahikeng?',
#     'What a very informative graphic this is. Well done.\nA real pity that government mis-handling has made it this way!\nI would really have liked us to come out with fewest deaths. https://t.co/gbjt7mwrfy',
#     'Easy transition from climate change denial to corona virus deaths denial. https://t.co/ofpV8sKWrk',
#     'Revealed: the secret report that gave ministers warning of care home coronavirus crisis https://t.co/74Mhf4fpg0 @Mike_Padgham @DebraClaridge @paulapeters2 @blueannoyed @blacktriangle1 @AnitaBellows12 @mmaher70 @Dis_PPL_Protest @DPACSheffield @jshannontreacy @johnpringdns',
#     'Hey, here&apos;s an idea if you want to switch up your exercise regime! \n\nhttps://t.co/oShssW2pNn',
#     'They shot children! Not that should shoot adults but they shot babies on their summer jobs 😭😭😭. The rest of the world is doing take out and drive through with minimal hiccups while Americans scream about their rights being violated and are shooting people. https://t.co/a9mcLAObFZ',
#     'It&apos;s the only reference point Britain has because it&apos;s the last success the country had*.\n\n*or 1966 world cup bollocks https://t.co/3PCh80RNU9',
#     'I have some ideas for them. Put a plastic bag over your head and you will be safe from any germs. https://t.co/8clUWry3NI',
#     'Leave homeless on the streets when all is WELL (not healthy to live on streets, ever)\n\nBring them into confined space when virus hits (not healthy)\n\nAlso give them addictive substances (not healthy)\n\n“Health department”\n\nWhy gov should never run our healthcare\n\n👇👇 https://t.co/BYUx5KIeOw',
#     'Revealed: the secret report that gave ministers warning of care home coronavirus crisis https://t.co/XYG4x6OJGR',
#     'ODD how @CBSNews @KMOV aren&apos;t reporting the Project Veritas FAKE NEWS story .. I wonder why???  https://t.co/69nOkgdS2Y',
#     'Because they aren’t stupid like England xoxo Good on ya Scotland https://t.co/870uTuGQW7',
#     'Magic Leap’s death throes have little to do with\xa0coronavirus https://t.co/kObyyCxzDA',
#     'New study reveals blueprint for getting out of Covid-19 lockdown - News - UEA https://t.co/qJspzqwJD4 #UEA',
#     'And when a person with #COVID19 coughs their germs into the air, then what? https://t.co/NLrpCmyc6g',
#     '@RandEnoch @Martinf683 @piersmorgan @MattHancock Because they generally have a highly-educated and pragmatic population who can generally be trusted with self-policed social distancing measures. Even then some bars &amp;amp; restaurants are failing:\nhttps://t.co/9a0S7KbpLO',
#     'This little guy was tested for coronavirus yesterday, just two weeks before his first birthday! Praying the results come back negative. But, how cute does he look with a mask!?😷 https://t.co/LlS3Xpi0Ia',
#     '#niet_in_journaal #US #military #COVID_19 Coronavirus survivors &quot;permanently disqualified&quot; from joining U.S. military, recruitment memo suggests https://t.co/bnKr7n31yC',
#     'Moderna shares surge after FDA approves coronavirus vaccine for phase 2 trial https://t.co/p1zSBB7BcY',
#     '$MRNA now aims to start a Phase 3 study of its coronavirus vaccine candidate by this summer, sooner than the initial guidance for the fall. \n\nFDA approved IND for company to move into Phase 2, which will begin shortly, Moderna says.',
#     'wtf ? https://t.co/ov4YpTmsZJ',
#     'Using covid crisis recovery to transform the NHS\nhttps://t.co/bMXvPnQlSJ',
#     'Hey, @MaynoothUni - can you send us all a 6-pack of McGargles to help us cope too? https://t.co/XwekRzUTtr',
#     '@HuffPostPol &quot;Widespread testing for coronavirus is unnecessary&quot; says the internet bot.\nIt’s just so fundamentally absurd that anyone can think this, is the response from a respected professor and medical analyst.\nTrump likes the bot&apos;s version so that becomes the truth; no checks no balances.',
#     'IRS Warns Public on COVID-19 Scams \nhttps://t.co/VHEVmyKbWy',
#     'The Coronavirus Circus Continues - LewRockwell https://t.co/f4eSMxOShQ',
#     'IRS Warns Public on COVID-19 Scams \nhttps://t.co/PpgATLiIrx',
#     '@REBRwanda @RwandaTV @gtwagirayezu Us he says, covid19 were affected education sector but we appreciate the feedback about eLearning program for helping students to sharp our minds',
#     '&apos;Political Virus&apos; Worst Than COVID-19 | Opinion | China Daily https://t.co/6b7pO7GyMN',
#     'The historian Paul Fussell once wrote of WWII “Chickenshit can be recognized instantly because it never has anything to do with winning the war.” There are a distressing number of local authorities eager to engage to chickenshit in the #coronavirus war. https://t.co/6fQtluzpdG',
#     'Hear from Covid-19 patient who had virus in\xa0December https://t.co/447QTWF5L0',
#     'We are scared because we cannot trust this Gov’t to do what is in our best interests! They are not bothered about how many people die, if NHS has correct PPE, if we are testing as many as we should be. They. Just. Don’t. Care! (Or at least that is what we feel). https://t.co/F2FTn9n9pN',
#     'As an assassination technique, this goes back to the Great Defenestration of Prague in 1419. Czech tradition and Soviet ambitions seems to have brought the technique into the Russian repertoire with the defenestration of Edvard Beneš in 1948. https://t.co/Ar8deWjki0']},
#   3832: {'ind': ['1258367403953500164',
#     '1258367405157466112',
#     '1258367406285762560',
#     '1258367407606960129',
#     '1258367407653040133',
#     '1258367407770472449',
#     '1258367408252817410',
#     '1258367408504528896',
#     '1258367408508743680',
#     '1258367408689033217',
#     '1258367408923914241',
#     '1258367409292894208',
#     '1258367410568036352',
#     '1258367410781876224',
#     '1258367412543590400',
#     '1258367412778524672',
#     '1258367412786864131',
#     '1258367412799508480',
#     '1258367412891770880',
#     '1258367412904382464',
#     '1258367413524918273',
#     '1258367414590472195',
#     '1258367415080988672',
#     '1258367415559368710',
#     '1258367415672606720',
#     '1258367415806832640',
#     '1258367416830234625',
#     '1258367419090944000',
#     '1258367419170488320',
#     '1258367419233570816',
#     '1258367419497828353',
#     '1258367419850149890',
#     '1258367420013645825',
#     '1258367420558909441',
#     '1258367420856537088',
#     '1258367421091545089',
#     '1258367422316384256',
#     '1258367423025209346',
#     '1258367424593829890',
#     '1258367424963006465',
#     '1258367424987947009',
#     '1258367425151729664',
#     '1258367425185275905',
#     '1258367425222979585',
#     '1258367427097870337',
#     '1258367427454226433',
#     '1258367428570087425',
#     '1258367428884680705',
#     '1258367429056565249',
#     '1258367429068984321',
#     '1258367429463457794',
#     '1258367429681561600',
#     '1258367431711641600',
#     '1258367431841443842',
#     '1258367432567242752',
#     '1258367432856567808',
#     '1258367433028636677',
#     '1258367433322237952'],
#    'content': ['@thehill Trump’s Ridiculous Behavior about Covid19 at Pandemic Briefings Battles https://t.co/4Gjy5tQ4XI https://t.co/8vcxU75Nz4',
#     '‘Complacent’ UK draws global criticism for Covid-19 response https://t.co/Qmd2GSQPY5',
#     '@Eglisecatho @Diocese72 +55 (22)981565421\nDon&apos;t you have a BRAIN?\nOnly (martial law)HOME PRISON, during 30 days, of all(100%) CITIZENS will stop CORONA VIRUS.\nNo more deaths.\nThe economy will be normal in 30 days too.\n CURE See Dra Eunara Negri discovered the CURE of CORONAVIRUS.\nhttps://t.co/2uLsT6Eehn',
#     'UK contact-tracing app could fall foul of privacy law, government told\n\nhttps://t.co/W85NfMKadm',
#     'Do you want to be up to date with #coronavirus worldwide? It is a good idea to attach this 👇 page to your sources. https://t.co/1mh5p6IQFz',
#     '2 Utah County businesses told staff to ignore COVID-19 guidelines, resulting in 68 positive cases | Local News | https://t.co/XhYEBoqOfJ https://t.co/q33WGNwikg',
#     'Are 2 mahine me kitni baar fake news doge https://t.co/esxocgOQ1D',
#     '@girlsreallyrule @joncoopertweets Speaking of investigations about bungled responses to the pandemic, there needs to be an investigation into the Trump Administration’s atrocious mismanagement of COVID19 in the USA.',
#     'Listen to this man all the way to the end. https://t.co/ttDtR278nG',
#     '@CortesSteve Cook Country #Democrats, especially @chicagosmayor &amp;amp; @ToniPreckwinkle, will &quot;goose&quot; step w/@GovPritzker, but - MANY counties around #Illinois that aren&apos;t so in bed with #Dems, where #Covid19/#CoronaVirus isn&apos;t so prevalent, should revolt &amp;amp; start to #reopenillinois, safely. #twill',
#     '@realDonaldTrump, @WhiteHouse Why can’t we see the #CDC #COVID19 recommendations? What are you hiding? https://t.co/SVeFHfsHmW',
#     '#KASARAGOD \n#KERALAHEALTHDEPARTMENT https://t.co/aKt7C9RQpz',
#     '@HillaryClinton How is trump “winding down” when people are still dying and we’re still quarantined? There’s still no immunization against this flu. Coronavirus isn’t taken as serious as it should. This is the first pandemic of the digital age and it’s not over!',
#     'As we bail out highly leveraged corporations and oil which was heading south prior to virus https://t.co/0onTRbY5Mn',
#     '@10DowningStreet please take note! https://t.co/Gb7tT4hqfn',
#     'Jaime Bofill highlights financial measures by #Spain &amp;amp; #eu to shield companies from economic effects of #covid19 #financialinstitutions #financialregulation https://t.co/fVKUkCynmC',
#     'New study reveals most Europeans support basic income after COVID-19 | University of Oxford https://t.co/kLywpLSS5o',
#     'I don’t trust the UN so maybe Assange should be moved to the US? 🤔 https://t.co/AUDL3P2jfT',
#     '@cjohansen_MT @goldiett7 @R_ZenBo But didn’t you worry about the servers of the food and how that could be unwittingly spreading covid19? We are avoiding dining in restaurants.',
#     'Apple Awards $10 Million to COVID-19 Testing Kit Maker From Advanced Manufacturing Fund. I Hate Everything.',
#     'So great to see @clubmaseratixxx in the latest update from @Brazzers and that too with @MarkusDupree ! Hope to see more of @BbwSofiaRose @MillyMarksxxx and @spitneyspears too ! #ThursdayThoughts #NursesDay2020 #BBW #COVID19 #Faptastic ! https://t.co/RIvpdHv2Kj',
#     'This is a great step in the right direction. Can we also stop the private sale of non #COVID19 test kids and the public sale of all test kids?!?! In fact, stop the sale of all kids, public or private!!! #kidsarepeopletoo #wellsorta #oknotreally #butalmost https://t.co/P2Si5ufZOf',
#     '@CNN UK has reported more than 30,000 deaths, highest in Europe\n\nLatest updates | # cases per million population👇\n\nhttps://t.co/TqfSuFkkLd\n#COVID19 #Covid_19',
#     'Due to #COVID19 aka #Coronavirus Ill be sending the first 350 people that like &amp;amp; retweet this up to $3000 through cashapp, apple pay, paypal or zelle (Must DM ME cashapp name or phone number first) https://t.co/PXLwZuNHRe',
#     '@BettGunther Your pretty picture does NOT accurately reflect WHO advice...you know that but it doesn&apos;t fit your story...  https://t.co/aTHxfMCcZG',
#     'Outsourcing the coronavirus crisis to business has failed – and NHS staff know it https://t.co/QOEJWb49Eu',
#     'BBC News - &quot;Men with advanced prostate #cancer can take highly targeted hormone therapies at home instead of coming into hospital for chemotherapy, @NHSEngland says&quot; - https://t.co/XYTzZIlOTP\n@ProstateUK @NewbCancerCare @macmillancancer @HealthwatchE @PHE_uk @KennetRadio #covid19',
#     'The PRC Sub-Committee on Refugees, Returnees &amp;amp; IDPs bureau held a vitual meeting to discuss the humanitarian challenges posed by #COVID19 pandemic &amp;amp; the toll on forced-displaced population \nThe Sub-Co commits to continue its work &amp;amp; mitigate the exacerbated humanitarian situation https://t.co/5lA2V3fNbn',
# ...
#     '@ABC Oh no..!  Now they&apos;re going to want to defund Coronavirus..!  And the dumb politicians will follow suit...',
#     'What can possibly go wrong when you have a president who does not give a f*** for science? https://t.co/NtbcALe8gr',
#     '#India #COVID19 https://t.co/XWGbIqnVj4',
#     'Delhi, the capital territory of India 🇮🇳, will open its borders tomorrow for the first time since the #COVID19 lockdown.\n\nRead on for more announcements 👇🏽 https://t.co/kAJkenAqIe',
#     'U.S. Diplomats Struggle to Defend Democracy Abroad Amid Crises at Home - The New York Times \u2066@madeleine\u2069 Warned us about this. Over and over. #TrumpOut2020 #VoteBlueToSaveAmerica  https://t.co/J7nwB9IvH7',
#     'Got to level before the coronavirus lockd….',
#     'Get 20% off any kind of background removing and photo editing.\n#white #transparent #photo_editing #Background_removal #cut_out\nASAP delivery with unlimited revisions until you are satisfied. Just check below\nhttps://t.co/UImGNwnqYZ\nwe are 24/7 promised to help you.\nThanks https://t.co/TkvI7j7FKc',
#     '#AgeQuodAgis https://t.co/m15a2M9BXS',
#     'Yes, but should have started about 30 years ago, thanks #NHS https://t.co/8NyI2o11Cj',
#     'Glad I&apos;m a software developer, otherwise this lockdown may of driven me nuts. https://t.co/VPgNLHQm6P',
#     'Cigna Newsroom | America&apos;s State of Mind: Use of Mental Health Medications Increasing with Spread of Coronavirus https://t.co/ijevNJ1k0l  @Cigna @ExpressScripts\n\n#Cigna #MentalHealth  #CoronaVirus #MentalHealthMedication',
#     'An interesting guide from #PwC on the challenges that many #media industry businesses may be facing due to #COVID19 and how to respond to them: https://t.co/c85XnCVt6B #COVID #COVID-19 #mediaindustry',
#     'Where was all this outrage when VE Day parties like this were gathering? Stop using Coronavirus as a way to air your opposition to the Black Lives Matter movement. https://t.co/eqOcsqPmoD',
#     'Quick question.. is racism over? https://t.co/sLeeDFxERO',
#     'In Ohio, the Department of Job and Family Services reports manufacturing employment dropped 13.79%. #Business #BusinessNews #Manufacturing #Coronavirus https://t.co/rVSy0086P5 https://t.co/WcnWpI2vVH',
#     '@Polly12YT @Haruka_Black1 But all protestors are participating in the spread of covid-19 which on twitter up until a week ago was “literally murdering others”',
#     'This is distressing. https://t.co/012nq3HPW0',
#     'So looking forward to talking with @adira_t @sivasaijeeva and Linda @GALAarchives tomorrow afternoon. Please join us live - or to listen again! https://t.co/6UDnhVlIXY',
#     '&quot;19 out of 40 rescue divers at a fire station in Stockholm are not allowed to dive as they have lung damage after covid-19&quot;\nhttps://t.co/e6t7iRHPFw\n\nSwedish government&apos;s strategy to get everyone infected is a war against its own population. https://t.co/MbGG672PJU',
#     'Boris Johnson&apos;s 11 fatal errors in handling coronavirus crisis which cost lives https://t.co/IcJSNdkspZ',
#     '@thomaskaine5 Covid19 is spiking in my town.  I’m staying in and wearing a mask when I have to go out.',
#     '&apos;All-pet private jet&apos; to reunite animals stranded during coronavirus pandemic\n\nhttps://t.co/VGcN7Iu9Pn',
#     '#NewsAlert | 191 fresh COVID-19 cases have been reported in Haryana taking the total tally to 4143. https://t.co/vu7bgfzxMY',
#     'Mustafa Centre, Tampines Mall and Geylang Serai market added to list of places visited by Covid-19 cases https://t.co/pUV0oTgfBB',
#     '#BlsckLivesMatter until we kill everyone with Coronavirus. Stay home people! https://t.co/wDEgEdOmyx',
#     'We&apos;re seeing, in real time, the result of politicizing masks.  Look at all these red states with exploding coronavirus outbreaks. https://t.co/zSif9FAMfz',
#     'BBC News - Coronavirus: Lockdown delay &apos;cost a lot of lives&apos;, says science adviser\nhttps://t.co/wYt4mE8Jh2',
#     'Religious places, shopping malls, restaurant hotels and offices which remained shut due to COVID-19 lockdown, set to reopen from tomorrow. https://t.co/lq571wQ6Yk',
#     'Data from Knox County shows a continuing rise in cases, going from 89 to 95 active cases since yesterday. (Thanks for the advice on the data y’all) https://t.co/uyvAo3EFeq',
#     'covid-19 sucks. https://t.co/EMFlpMI14T via @YouTube',
#     'Everyone stay safe out there and remember #BlackLivesMattter 🖤 https://t.co/cA4HcM2Zup',
#     'With Kashmir valley witnessing surge in number of Covid-19 cases,Doctors\xa0Association Kashmir (DAK) on Sunday said reopening of economic activities in presence of high degree of virus transmission would be risky.',
#     'So may hospitals in #Delhi are not accepting #COVID19 patients. I have read about so many cases by patients are their relatives. Whats @ArvindKejriwal doing? Just giving speeches. Shame on @ArvindKejriwal',
#     '#CoronaVirusindia Bhopal administration decides to not reopen places of worship from tomorrow. #CoronaVirus #Covid19 #pandemic #CoronaVirusUpdates #bhopal #MadhyaPradesh #religion',
#     'This comes after a private meeting w/ members of Gov. Gavin Newsom&apos;s staff who revealed that in #California, the #coronavirus did not spread first from a nail salon, unlike what the governor said in May. On #Facebook, nail techs echo one another, saying they’ve been “waiting...&quot;',
#     'Imposing lockdown to prevent coronavirus is causing many problems for students studying in all kinds of educational institutions across the country.\n#GeneralPromotion4BihariStudents',
#     '199 more cases take coronavirus tally to 4,659 in Andhra Pradesh\nhttps://t.co/HSTQOHgB48',
#     'The End of College as We Knew It? https://t.co/F8uz3GTqSa Colleges and universities are in trouble — serious trouble.  We need, writers, philosophers, historians.  Not sure we&apos;re going to get that.',
#     '#Apple Releases #Apple Maps Mobility Data Trends Tool to Help Mitigate COVID-19 Spread\nhttps://t.co/DWWgMnkAA9',
#     '@CTVNews Virus is BS quit testing https://t.co/MVN9vOm9J4',
#     '@Tandy91573262 @pure_squall9 @lilym326 @the_resistor @realDonaldTrump Yes, Cuomo signed an order to make Nursing Homes take in Covid19 patients. Literally killed all your Grandparents. But hey it&apos;s &quot;tRumps&quot; fault right? \nhttps://t.co/ZlFc2nbIwN',
#     '&quot;When it comes to coronavirus and health concerns, building owners and operators need to avoid making promises they can’t keep.&quot; Read more on @GlobeStcom https://t.co/0rJsrXpDhu #SIOR #CRE #COVID19 #reenty']},
#   3834: {'ind': ['1269647468557451264',
#     '1269647469555507200',
#     '1269647469824159744',
#     '1269647470201577474',
#     '1269647472189734915',
#     '1269647472508514304',
#     '1269647472877613057',
#     '1269647472898564099',
#     '1269647473015951360',
#     '1269647475637436420',
#     '1269647476388061184',
#     '1269647477558464512',
#     '1269647478653140996',
#     '1269647478745296897',
#     '1269647480376840192',
#     '1269647480632770563',
#     '1269647480725082115',
#     '1269647482377699329',
#     '1269647483073945600',
#     '1269647483254091776',
#     '1269647485322104837',
#     '1269647486286774273',
#     '1269647486735446017',
#     '1269647487293218816',
#     '1269647488774033408',
#     '1269647490367750146',
#     '1269647490997006336',
#     '1269647491814821888',
#     '1269647492263505920',
#     '1269647493773615104',
#     '1269647493832364032',
#     '1269647494457233410',
#     '1269647494935388160',
#     '1269647495002566656',
#     '1269647495153487878',
#     '1269647495640031234',
#     '1269647495770112002',
#     '1269647498001420288',
#     '1269647498286686208',
#     '1269647498710265856',
#     '1269647499175829507',
#     '1269647499226157062',
#     '1269647500400615425',
#     '1269647501050753026',
#     '1269647501440811009',
#     '1269647505781743618',
#     '1269647506750742530',
#     '1269647506952138753',
#     '1269647507375616005'],
#    'content': ['COVID-19 recovery: Countries need to target broad development challenges – World\xa0Bank https://t.co/Q5qLoY8Add',
#     'my last three white cells trying to fight coronavirus https://t.co/pNUmcyK6Xs',
#     'See? https://t.co/dpsmW5YxPw',
#     'Senior doctors do not attend to us, say COVID-19 patients at\xa0Victoria https://t.co/2NA2qYhqJo',
#     'I’ve just heard that people who’ve tested themselves for Covid-19 antibodies have had a refund and no results back. Has anyone else had this?',
#     'Maharashtra crosses China’s official tally of positive COVID-19\xa0cases https://t.co/Wksl5g7GlE',
#     'See that little squiggly line way at the very bottom of the chart, hugging zero?  Coronavirus deaths in Greece. They beat the virus.  How&apos;d they do it? This article says bringing in 5 tons of chloroquine and using it from the start had a lot to do with it. https://t.co/6SglFhtsNx https://t.co/J3T2t2tlic',
#     'One more died of Covid-19 in #Mehsana  #Gujarat - media source',
#     '#Covid19 Excitement #Masks Sorrento’s Disastrous Capital Structure | Social Reach: Low https://t.co/KK1Qz1biCH',
#     'Go to Florida &amp;amp; die from coronavirus. https://t.co/dHE3F5NgBw',
#     '#mufc have renewed their interest in Donny van de Beek and are weighing up a bid. Real Madrid have agreed an outlined €55m deal with Ajax but the coronavirus pandemic has left the player uncertain whether Real can sign him this summer [times]\nOn or off?',
#     '@PCMCSarathi #PCMCCOVID19UPDATES just a thought:compare our Pune &amp;amp; Bangalore, both are similar in many aspects- old city, IT hub, large business travellers, mix of culture, employees-skilled, semi skilled, unskilled.\nHow Blore managed covid19 better? Should we adopt something?',
#     '#Kentucky keep @senatemajldr in #KY\n\nAmerica, it’s imperative we #FlipTheSenateBlue regardless of who is President or we WILL have 4 more years of #Obstruction in Congress - 12 yrs is already too many!\n\n#healthcare \n#Justice\n#Voting\n#COVID19 \n#Truth\n#transparency \n#Equality https://t.co/gR5X5CSWy4',
#     '@latimes #BoycottLATimes. Under mining slow store opening - the immediate opening trump promotes in other states resulted in higher Covid19 cases and deaths.  @GavinNewsom  issued phased roll out is the Correct approach. Nail shops are NOT essential',
#     'The retractions reveal a bias. An eagerness to keep the public misled regarding the efficancy of hydroxychloroquine. https://t.co/m5pXNn6KtF',
#     'Hong Kong’s recovery from coronavirus and protests depends on employers joining subsidy scheme https://t.co/fAhpz9eWeA',
#     'Kenya: Police Killed At Least 15 Since Start Of Coronavirus Curfew․ https://t.co/mB8jedFZsa\n#sikuzakiama #sundayvibes #MpakaChee #COVID19 #yansh #SiayaCounty #13reasonswhyseason4 #SundayThoughts',
#     'Sustainable investing is set to surge in the wake of the coronavirus pandemic. https://t.co/MlFfxQfUJp',
#     'Global coronavirus death toll tops 400,000 as protesters continue to defy lockdowns https://t.co/N1hR0HXZdY via @nbcnews',
#     'What do we want, we want all protester to fuck off home, I can’t hug my mum or dad, but it’s ok for you cunts to protest #BlackLivesMattters #COVIDIDIOTS #COVID19',
#     'They had to grow the trees first. https://t.co/YB6JyAuVcR',
#     '@jairbolsonaro @govbr @minsaude https://t.co/sVCVtJkiKI\nGOVERNO GENOCIDA OCULTANDO CADÁVERES.\n#ForaBolsonaro',
#     'Looks like Tom Cotton is now writing headlines too for \u2066@nytimes\u2069  https://t.co/KfSPFSAhQE',
#     'So,  Covid-19 can infect learners who don&apos;t show symptoms... and the same learners stay with their grandparents who have underline conditions that could kill them if Covid-19 had to come to the party? \n\n#schoolreopening https://t.co/1bAelMrdLI',
#     'So EVERYTHING I learned about viruses 🦠 for that microbiology degree I paid good money for is a lie.\n#COVID19 only spreads if small businesses are open, you stand closer than 6ft or have a party with 12+ guests - but not for protests containing 100s. 🤡 🌎 #BiologyDegreeRefund https://t.co/eVvRxZHyQm',
#     '#Covid19 bot \n#COVID19 last 5 days stats #Dadra and Nagar Haveli and Daman and Diu\nConfirmed Cases trend\n02-Jun - 0\n03-Jun - 8\n04-Jun - 3\n05-Jun - 0\n06-Jun - 5\n#CoronavirusPandemic #COVID19India #coronavirus #IndiaFightsCorona #StayHome #StaySafe',
#     'Boris the Killer https://t.co/0PCxCSVCHw',
#     '@theegibster @deanseavy @JL_Chapman Seems like he stole a play from China’s Coronavirus reporting playbook “How to Lie With Statistics” : https://t.co/KoiH5njCd1']}}}

# %% [markdown]
# ## Output to XML

# %%
# sort the date
date = sorted(output_dict.keys())
date
# Out:
# ['2020-04-18', '2020-05-07', '2020-05-12', '2020-06-07']

# %%
batch_no = []
# sort the batch no for each date
for i in date:
    b = sorted(output_dict[i].keys())
    batch_no.append(b)

batch_no
# Out:
# [[8, 30], [3830, 3831, 3832, 3833, 3834], [1, 26], [3831, 3832, 3833, 3834]]

# %%
# write all the output to an xml file
f = open('output.xml', 'w',encoding="utf-8")

f.write('<?xml version="1.0" encoding="UTF-8"?>\n')
f.write('<data>\n')

for d in range(len(date)):
    f.write('<tweets date="' + str(date[d])+'">\n')
    for b in range(len(batch_no[d])):
        for t in range(len(output_dict[date[d]][batch_no[d][b]]['ind'])):
            f.write('<tweet id="' + output_dict[date[d]][batch_no[d][b]]['ind'][t] + '">' + \
                    output_dict[date[d]][batch_no[d][b]]['content'][t] + '</tweet>\n')
    f.write('</tweets>\n')
    
f.write('</data>')
f.close()
