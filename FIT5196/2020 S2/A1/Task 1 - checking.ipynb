# %%
import langid
import re

# %%
f = open('3038508.xml','r',encoding = 'utf8')
output = f.read()
output
# Out:
# '<?xml version="1.0" encoding="UTF-8"?>\n<data>\n<tweets date="2020-04-18">\n<tweet id="1251361301282029569">@Coach_Keesha @BrandonBeckham_ @TheDemocrats @realDonaldTrump Democrats propose bill to undo Trump&apos;s move of firing coronavirus oversight leader.\n&quot;There are trillions of taxpayer dollars at stake, and Americans across the political spectrum want those funds to be spent without waste, fraud, abuse or profiteering.&quot;\nhttps://t.co/m9ljqeITeE</tweet>\n<tweet id="1251361303966425090">@Ska_Maria And over a month later, still we track Italy https://t.co/vEMV43dvsJ https://t.co/VuqOYihukZ</tweet>\n<tweet id="1251361304297615361">@GinSecurities @WCCO @carlquintanilla @GovTimWalz @GOP @DNC @CNN Where are you getting your information? COVID-19 does not care about your political affiliation.</tweet>\n<tweet id="1251361304725651456">Looking into reports that #coronavirus escaped from #Wuhan lab, says Donald #Trump https://t.co/W7kWVjOasU https://t.co/1dGhSMOE72</tweet>\n<tw
# ...

# %%
g = open('sample.xml','r',encoding = 'utf-8')
sample = g.read()

# %%
date_twit_output = re.findall(r'<tweets date=[\w\W]+?</tweets>', output)
len(date_twit_output)
# Out:
# 4

# %%
date_twit_sample = re.findall(r'<tweets date=[\w\W]+?</tweets>', sample)
len(date_twit_sample)
# Out:
# 4

# %%
date_twit_sample[0]
# Out:
# '<tweets date="2020-06-07">\n<tweet id="1269647338626318336">#FechadoComBolsonaroAte2026 https://t.co/rGKviMCEwK</tweet>\n<tweet id="1269647339595186176">The latest The Long-term Care Daily! https://t.co/14QmxdyuXJ Thanks to @PerfumeFlogger @IPACCanada #covid19 #halifax</tweet>\n<tweet id="1269647339700002818">SAFETY FIRST\n\ncc : danielist_\n#safetyfirst #safe #covid19 #malaysia #kedah #riverfront #ootd #style #done @ White Mustache https://t.co/gHqsEguqVG</tweet>\n<tweet id="1269647339712581634">Learn about tips to keep your car running smoothly, even if it&apos;s been sitting at home for the past few months. #cars #carmaintenance #covid19 https://t.co/yb5f0skRpK</tweet>\n<tweet id="1269647341474250752">Whatttt https://t.co/6WGknbjxUk</tweet>\n<tweet id="1269647343248388096">Plant-derived drug under testing, cancer drug shows promise: Covid-19 vaccine update\xa0 – world\xa0news https://t.co/rKxRQXXNZM</tweet>\n<tweet id="1269647343588126724">Our #COVID19  Resource Hub provides ongo
# ...

# %%
new_date_twit_sample = [date_twit_sample[1],date_twit_sample[3],date_twit_sample[2],date_twit_sample[0]]

# %%
date_twit_output
# Out:
# ['<tweets date="2020-04-18">\n<tweet id="1251361301282029569">@Coach_Keesha @BrandonBeckham_ @TheDemocrats @realDonaldTrump Democrats propose bill to undo Trump&apos;s move of firing coronavirus oversight leader.\n&quot;There are trillions of taxpayer dollars at stake, and Americans across the political spectrum want those funds to be spent without waste, fraud, abuse or profiteering.&quot;\nhttps://t.co/m9ljqeITeE</tweet>\n<tweet id="1251361303966425090">@Ska_Maria And over a month later, still we track Italy https://t.co/vEMV43dvsJ https://t.co/VuqOYihukZ</tweet>\n<tweet id="1251361304297615361">@GinSecurities @WCCO @carlquintanilla @GovTimWalz @GOP @DNC @CNN Where are you getting your information? COVID-19 does not care about your political affiliation.</tweet>\n<tweet id="1251361304725651456">Looking into reports that #coronavirus escaped from #Wuhan lab, says Donald #Trump https://t.co/W7kWVjOasU https://t.co/1dGhSMOE72</tweet>\n<tweet id="1251361304893325319">The presidency reg
# ...

# %%
new_date_twit_sample
# Out:
# ['<tweets date="2020-04-18">\n<tweet id="1251361301282029569">@Coach_Keesha @BrandonBeckham_ @TheDemocrats @realDonaldTrump Democrats propose bill to undo Trump&apos;s move of firing coronavirus oversight leader.\n&quot;There are trillions of taxpayer dollars at stake, and Americans across the political spectrum want those funds to be spent without waste, fraud, abuse or profiteering.&quot;\nhttps://t.co/m9ljqeITeE</tweet>\n<tweet id="1251361303966425090">@Ska_Maria And over a month later, still we track Italy https://t.co/vEMV43dvsJ https://t.co/VuqOYihukZ</tweet>\n<tweet id="1251361304297615361">@GinSecurities @WCCO @carlquintanilla @GovTimWalz @GOP @DNC @CNN Where are you getting your information? COVID-19 does not care about your political affiliation.</tweet>\n<tweet id="1251361304725651456">Looking into reports that #coronavirus escaped from #Wuhan lab, says Donald #Trump https://t.co/W7kWVjOasU https://t.co/1dGhSMOE72</tweet>\n<tweet id="1251361304893325319">The presidency reg
# ...

# %%
new_date_twit_sample == date_twit_output
# Out:
# False
